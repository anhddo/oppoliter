# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 20000
x = np.arange(n)
plt.plot(x, 0.9993**x)

# %%
from datetime import datetime

# %%
str(datetime.now())
# Out:
# '2020-05-19 11:24:34.892996'
