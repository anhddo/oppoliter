# %%
import pandas as pd

# %%
cd ../tmp/n_chain

# %%
ls

# %%
df['reward']

# %%
mv opt_100_50000 opt_100_50000_correct

# %%
df_opt = pd.read_csv('opt_100_50000')

# %%
df_opt_zero = pd.read_csv('opt_100_50000_zero')
df_opt = pd.read_csv('opt_100_50000')
df_opt['reward'].cumsum().plot()
df_opt_zero['reward'].cumsum().plot()

# %%
df_opt_zero = pd.read_csv('noex_100_50000')
df_opt = pd.read_csv('opt_100_50000')
ax = df_opt['reward'].cumsum().plot()
df_opt_zero['reward'].cumsum().plot()
ax.legend(['Optimistic', 'No exploration'])
ax.set_ylabel('reward')
# Out:
# Text(0, 0.5, 'reward')

# %%
df_noex = pd.read_csv('noex_100_50000_zero')
df_opt = pd.read_csv('opt_100_50000_zero')
ax = df_opt['reward'].cumsum().plot()
df_noex['reward'].cumsum().plot()
ax.legend(['Optimistic', 'No exploration'])
ax.set_title('Q[s,a]=0')
ax.set_ylabel('reward')
# Out:
# Text(0, 0.5, 'reward')

# %%
df['reward']
# Out:
# 0        0.00
# 1        0.01
# 2        0.00
# 3        0.00
# 4        0.00
#          ...
# 49995    0.00
# 49996    1.00
# 49997    0.00
# 49998    1.00
# 49999    0.00
# Name: reward, Length: 50000, dtype: float64

# %%
ls
# Out:
# noex_100_50000_correct  opt_100_50000           opt_100_50000_zero
# noex_100_50000_zero     opt_100_50000_correct

# %%
df_opt = pd.read_csv('opt_100_50000')
df_noex = pd.read_csv('noex_100_50000')
ax = df_opt['reward'].cumsum().plot()
df_noex['reward'].cumsum().plot()
ax.legend(['Optimistic', 'No exploration'])
ax.set_ylabel('reward')
ax.set_title('Q[s,a]=0')
# Out:
# Text(0.5, 1.0, 'Q[s,a]=0')

# %%
df_opt = pd.read_csv('opt_100_50000')
df_noex = pd.read_csv('noex_100_50000')
ax = df_opt['reward'].cumsum().plot()
df_noex['reward'].cumsum().plot()
ax.legend(['Optimistic', 'No exploration'])
ax.set_ylabel('reward')
ax.set_title('Q[s,a]=0')
# Out:
# Text(0.5, 1.0, 'Q[s,a]=0')

# %%
df_opt = pd.read_csv('opt_25_1000000')
df_noex = pd.read_csv('noex_25_1000000')
ax = df_opt['reward'].cumsum().plot()
df_noex['reward'].cumsum().plot()
ax.legend(['Optimistic', 'No exploration'])
ax.set_ylabel('reward')
ax.set_title('Q[s,a]=0')
# Out:
# Text(0.5, 1.0, 'Q[s,a]=0')
# /Users/anhdo/.pyenv/versions/3.7.4/envs/3.7.4-env/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df_opt = pd.read_csv('opt_25_100000')
df_noex = pd.read_csv('noex_25_100000')
ax = df_opt['reward'].cumsum().plot()
df_noex['reward'].cumsum().plot()
ax.legend(['Optimistic', 'No exploration'])
ax.set_ylabel('reward')
ax.set_title('Q[s,a]=0')
# Out:
# Text(0.5, 1.0, 'Q[s,a]=0')

# %%
len(df_noex['reward'])
# Out:
# 3000000

# %%
len(df_opt['reward'])
# Out:
# 3000000

# %%
df_opt = pd.read_csv('opt_25_3000000')
df_noex = pd.read_csv('noex_25_3000000')
ax = df_noex['reward'].cumsum()[::1000].plot()
df_opt['reward'].cumsum()[::1000].plot()

ax.legend(['No exploration', 'Optimistic'])
ax.set_ylabel('reward')
ax.set_title('Q[s,a]=0')
# Out:
# Text(0.5, 1.0, 'Q[s,a]=0')

# %%
ls
# Out:
# noex_100_50000          noex_50_100000          opt_25_100000
# noex_100_50000_correct  noex_50_50000           opt_25_1000000
# noex_100_50000_zero     opt_100_50000           opt_50_100000
# noex_10_50000           opt_100_50000_correct   opt_50_50000
# noex_25_100000          opt_100_50000_zero
# noex_25_1000000         opt_10_50000
